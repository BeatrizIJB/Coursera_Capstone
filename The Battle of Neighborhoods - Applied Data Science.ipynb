# %% [markdown]
# # The Battle of Neighborhoods - Applied Data Science Capstone
#
# ## Project:

# %% [markdown]
# First step: Install the python packages and libraries

# %%
#Install packages if needed

#pip install folium
#pip install geopy
#pip install geopandas
#pip install geojson
#pip install lxml
#pip install bs4

from urllib.request import urlopen

import pandas as pd
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt

import folium # map rendering library
from folium import plugins
from folium.plugins import HeatMap

import requests
from bs4 import BeautifulSoup
import numpy as np # library to handle data in a vectorized manner
import json # library to handle JSON files
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import geopandas as gpd



print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# #### Scraping the dataset from the Web Page of Lisbon's City Council

# %%
list_url = "https://geodados-cml.hub.arcgis.com/datasets/miradouros/data"
source = requests.get(list_url).text
soup = BeautifulSoup(source, 'xml')
table=soup.find('table')

# %%
#Create dataframe
column_names = ['OBJECTID','COD_SIG','IDTIPO','CAT_NOME','CAT_ID','INF_ID','INF_NOME','INF_MORADA','INF_TELEFONE','INF_FAX','INF_EMAIL','INF_SITE','INF_DESCRICAO','INF_AUTOR_DESCRICAO','INF_FONTE','INF_OBS','INF_ACTIVO','INF_MUNICIPAL','GlobalID']
df = pd.DataFrame(columns = column_names)

# %%
for tr_cell in table.find_all('tr'):
    row_data=[]
    for td_cell in tr_cell.find_all('td'):
        row_data.append(td_cell.text.strip())
    if len(row_data)==3:
        df.loc[len(df)] = row_data
df
# Out:
#     OBJECTID        COD_SIG IDTIPO                             CAT_NOME  \
# 0          1  0805531053001      2  Espaços Verdes e Lazer - Miradouros
# 1          2  0202512431001      2  Espaços Verdes e Lazer - Miradouros
# 2          3             16      7  Espaços Verdes e Lazer - Miradouros
# 3          4             41      7  Espaços Verdes e Lazer - Miradouros
# 4          5             20      7  Espaços Verdes e Lazer - Miradouros
# 5          6             23      7  Espaços Verdes e Lazer - Miradouros
# 6          7             32      7  Espaços Verdes e Lazer - Miradouros
# 7          8              4      7  Espaços Verdes e Lazer - Miradouros
# 8          9             21      7  Espaços Verdes e Lazer - Miradouros
# 9         10             11      7  Espaços Verdes e Lazer - Miradouros
# 10        11             13      7  Espaços Verdes e Lazer - Miradouros
# 11        12             28      7  Espaços Verdes e Lazer - Miradouros
# 12        13              2      7  Espaços Verdes e Lazer - Miradouros
# 13        14             33      7  Espaços Verdes e Lazer - Miradouros
# 14        15              7      7  Espaços Verdes e Lazer - Miradouros
# 15        16              5      7  Espaços Verdes e Lazer - Miradouros
# 16        17             31      7  Espaços Verdes e Lazer - Miradouros
# 17        18             30      7  Espaços Verdes e Lazer - Miradouros
# 18        19              6      7  Espaços Verdes e Lazer - Miradouros
# 19        20              3      7  Espaços Verdes e Lazer - Miradouros
#
#     CAT_ID  INF_ID                                           INF_NOME  \
# 0   211819   12514                Miradouro do Panorâmico de Monsanto
# 1   211819   12522                                Experiência Pilar 7
# 2   211819    3232                         Miradouro de Santo Estêvão
# 3   211819    1948                  Miradouro do Castelo de São Jorge
# 4   211819    1958  Miradouro Sophia de Mello Breyner Andresen (Mi...
# 5   211819    1960                           Miradouro de Santa Clara
# 6   211819    3233                   Miradouro da Basílica da Estrela
# 7   211819    1965                                 Miradouro do Torel
# 8   211819    1959                        Miradouro das Portas do Sol
# 9   211819    1953             Miradouro do Padrão dos Descobrimentos
# 10  211819    2139              Miradouro da Rocha de Conde de Óbidos
# 11  211819    1961                       Miradouro da Penha de França
# 12  211819    1957                           Miradouro de Santa Luzia
# 13  211819   12050                           Miradouro de Santo Amaro
# 14  211819    1945                    Miradouro do Parque Eduardo VII
# 15  211819    1947                Miradouro de São Pedro de Alcântara
# 16  211819    1964                           Miradouro do Monte Agudo
# 17  211819    1963                        Miradouro da Torre de Belém
# 18  211819    1946                        Miradouro de Santa Catarina
# 19  211819    1962                      Miradouro da Senhora do Monte
#
#                                        INF_MORADA       INF_TELEFONE INF_FAX  \
# 0                              Estrada Bela Vista               None    None
# 1   Avenida da Índia, Ponte 25 de Abril - Pilar 7    +351 211117880     None
# 2                          Largo de Santo Estêvão   +351 213 912 600    None
# 3                            Castelo de São Jorge   +351 218 800 620    None
# 4                                  Largo da Graça  (351) 213 912 600    None
# 5                            Campo de Santa Clara   +351 218 533 270    None
# 6               Praça da Estrela\n1200-667 LISBOA   +351 213 960 915    None
# 7                           Rua Júlio de Andradel               None    None
# 8                       Largo das Portas do Sol\n   +351 213 912 600    None
# 9                           Avenida de Brasília\n   +351 213 031 950    None
# 10                        Rua Presidente Arriaga;   +351 213 912 600    None
# 11      Largo da Penha de França\n1170-298 LISBOA  (351) 213 912 600    None
# 12                         Largo de Santa Luzia\n               None    None
# 13                         Calçada de Santo Amaro               None    None
# 14                    Alameda Cardeal Cerejeira\n   +351 213 912 600    None
# 15                  Rua de São Pedro de Alcântara   +351 213 912 600    None
# 16                          Rua Heliodoro Salgado  (351) 213 912 600    None
# 17                 Avenida de Brasília\n1400-038    +351 213 620 034    None
# 18         Rua de Santa Catarina\n1200-403 LISBOA   +351 213 027 700    None
# 19                               Largo do Monte\n               None    None
#
#                           INF_EMAIL  \
# 0                              None
# 1              info@lismarketing.pt
# 2                 daev@cm-lisboa.pt
# 3         info@castelodesaojorge.pt
# 4                 daev@cm-lisboa.pt
# 5                 daev@cm-lisboa.pt
# 6                              None
# 7                              None
# 8                 daev@cm-lisboa.pt
# 9   info@padraodosdescobrimentos.pt
# 10                daev@cm-lisboa.pt
# 11                daev@cm-lisboa.pt
# 12                             None
# 13                             None
# 14                daev@cm-lisboa.pt
# 15                daev@cm-lisboa.pt
# 16                daev@cm-lisboa.pt
# 17            mjeronimos@igespar.pt
# 18                             None
# 19                             None
#
#                                              INF_SITE  \
# 0                                                None
# 1                                www.visitlisboa.com
# 2                                                None
# 3                            www.castelodesaojorge.pt
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                      www.padraodosdescobrimentos.pt
# 10  http://lisboaverde.cm-lisboa.pt/index.php?id=4345
# 11  http://lisboaverde.cm-lisboa.pt/index.php?id=5561
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                 www.torrebelem.pt/
# 18                                               None
# 19                                               None
#
#                                         INF_DESCRICAO  \
# 0   Localizado no Parque Florestal de Monsanto, na...
# 1                                                None
# 2   Situado no coração de Alfama, do adro da Igrej...
# 3   O Castelo de São Jorge oferece uma vista privi...
# 4   Localizado junto à Igreja e antigo Convento da...
# 5   É um ponto alto da cidade com vista panorâmica...
# 6   Do zimbório desfruta-se de bela vista: a oeste...
# 7   Deste miradouro disfruta-se de uma vista desaf...
# 8   Localizado no Largo das Portas do Sol, daí o s...
# 9   No terraço existe um espetacular miradouro, do...
# 10  Este miradouro, enquadrado por um conjunto de ...
# 11  Vista inesquecível quer para o Vale do Tejo co...
# 12  Uma das mais belas janelas sobre o rio Tejo e ...
# 13                                               None
# 14  Está integrado no PARQUE EDUARDO VII, e  tem u...
# 15  Do miradouro de São Pedro de Alcântara, locali...
# 16  Com uma vista deslumbrante sobre a cidade, o M...
# 17  Do terraço da torre tem-se ampla vista do estu...
# 18  A partir deste miradouro podemos observar o Te...
# 19  Junto à Capela da Senhora do Monte, este balcã...
#
#                                   INF_AUTOR_DESCRICAO             INF_FONTE  \
# 0                                                None                DMEVAE
# 1                                                None  www.visitlisboa.com
# 2                                                None                     -
# 3                                       Isabel Santos                     -
# 4   Oásis Alfacinhas: Guia Ambiental de Lisboa - I...                     -
# 5                                                None                     -
# 6                                                None                     -
# 7                                                None                     -
# 8   http://revelarlx.cm-lisboa.pt, www.guiadacidad...                     -
# 9                                                None                     -
# 10                   Oásis Alfacinhas - Isabel Santos                     -
# 11                                               None                     -
# 12                   Oásis Alfacinhas - Isabel Santos                     -
# 13                                               None                     -
# 14                                               None                     -
# 15  Guia: Lisboa,Uma cidade inesquecível, Oásis Al...                     -
# 16                                               None                     -
# 17                                               None                     -
# 18  Guia: Lisboa. Uma cidade inesquecível, Oásis A...                     -
# 19                                               None                     -
#
#    INF_OBS  INF_ACTIVO  INF_MUNICIPAL                              GlobalID
# 0     None           1              0  6eed37fd-2b1c-4d74-bf46-651b8b94737d
# 1     None           1              0  783577af-9715-49a8-a797-b6cef6a60d69
# 2   SG/DMC           1              0  51166c6a-a6bf-4d6a-9fdf-b2490dc737b6
# 3     None           1              0  8ced2062-5a41-479a-927f-d17cadd6352a
# 4     None           1              1  fd96eabc-2570-4094-831c-3c54e5a4133d
# 5   SG/DMC           1              0  8cf5bdec-709c-45c9-9c61-4be75aeb0146
# 6   SG-DMC           1              0  48fbfa88-0ee2-449a-a6fa-98bf29696738
# 7   SG/DMC           1              0  1cd6490b-e68e-4a34-9a27-c654ef3124e8
# 8     None           1              1  229ec52c-ec31-4bf4-a471-b4db75912df9
# 9     None           1              1  ce95a050-404d-4678-8cae-fdff207bc983
# 10    None           1              0  6f536056-3675-424e-9333-c3f9a3ed73e8
# 11  SG-DMC           1              0  3b560443-d244-43d0-a60e-91e9b505d0da
# 12    None           1              1  a6939081-dc3a-4335-a7f1-36d8a02f7a6c
# 13    None           1              0  44dbab8e-86a0-44ed-b190-ce166b834918
# 14  SG/DMC           1              0  8bb025f7-a443-48ab-9380-01e2de6a172c
# 15    None           1              0  ae865bdf-b7aa-4dd1-b8a0-231d35472b6c
# 16  SG-DMC           1              0  000efa7b-6c61-4974-8aee-9dca558cdccb
# 17  SG-DMC           1              0  3b5951f1-629e-4f48-932f-eac38b074e0b
# 18    None           1              0  f4b1ba6c-394d-4fbb-8c2d-7f7049faa687
# 19    None           1              1  eb681f37-e209-4fa5-976d-f3d4839de060

# %%
df.shape
# Out:
# (20, 19)

# %%
Lisbon_viewpoints_geodf = gpd.read_file('https://opendata.arcgis.com/datasets/02763aa9ec6b4d719841f713e682b12a_1.geojson')
df = Lisbon_viewpoints_geodf

df
# Out:
#     OBJECTID        COD_SIG IDTIPO                             CAT_NOME  \
# 0          1  0805531053001      2  Espaços Verdes e Lazer - Miradouros
# 1          2  0202512431001      2  Espaços Verdes e Lazer - Miradouros
# 2          3             16      7  Espaços Verdes e Lazer - Miradouros
# 3          4             41      7  Espaços Verdes e Lazer - Miradouros
# 4          5             20      7  Espaços Verdes e Lazer - Miradouros
# 5          6             23      7  Espaços Verdes e Lazer - Miradouros
# 6          7             32      7  Espaços Verdes e Lazer - Miradouros
# 7          8              4      7  Espaços Verdes e Lazer - Miradouros
# 8          9             21      7  Espaços Verdes e Lazer - Miradouros
# 9         10             11      7  Espaços Verdes e Lazer - Miradouros
# 10        11             13      7  Espaços Verdes e Lazer - Miradouros
# 11        12             28      7  Espaços Verdes e Lazer - Miradouros
# 12        13              2      7  Espaços Verdes e Lazer - Miradouros
# 13        14             33      7  Espaços Verdes e Lazer - Miradouros
# 14        15              7      7  Espaços Verdes e Lazer - Miradouros
# 15        16              5      7  Espaços Verdes e Lazer - Miradouros
# 16        17             31      7  Espaços Verdes e Lazer - Miradouros
# 17        18             30      7  Espaços Verdes e Lazer - Miradouros
# 18        19              6      7  Espaços Verdes e Lazer - Miradouros
# 19        20              3      7  Espaços Verdes e Lazer - Miradouros
#
#     CAT_ID  INF_ID                                           INF_NOME  \
# 0   211819   12514                Miradouro do Panorâmico de Monsanto
# 1   211819   12522                                Experiência Pilar 7
# 2   211819    3232                         Miradouro de Santo Estêvão
# 3   211819    1948                  Miradouro do Castelo de São Jorge
# 4   211819    1958  Miradouro Sophia de Mello Breyner Andresen (Mi...
# 5   211819    1960                           Miradouro de Santa Clara
# 6   211819    3233                   Miradouro da Basílica da Estrela
# 7   211819    1965                                 Miradouro do Torel
# 8   211819    1959                        Miradouro das Portas do Sol
# 9   211819    1953             Miradouro do Padrão dos Descobrimentos
# 10  211819    2139              Miradouro da Rocha de Conde de Óbidos
# 11  211819    1961                       Miradouro da Penha de França
# 12  211819    1957                           Miradouro de Santa Luzia
# 13  211819   12050                           Miradouro de Santo Amaro
# 14  211819    1945                    Miradouro do Parque Eduardo VII
# 15  211819    1947                Miradouro de São Pedro de Alcântara
# 16  211819    1964                           Miradouro do Monte Agudo
# 17  211819    1963                        Miradouro da Torre de Belém
# 18  211819    1946                        Miradouro de Santa Catarina
# 19  211819    1962                      Miradouro da Senhora do Monte
#
#                                        INF_MORADA       INF_TELEFONE INF_FAX  \
# 0                              Estrada Bela Vista               None    None
# 1   Avenida da Índia, Ponte 25 de Abril - Pilar 7    +351 211117880     None
# 2                          Largo de Santo Estêvão   +351 213 912 600    None
# 3                            Castelo de São Jorge   +351 218 800 620    None
# 4                                  Largo da Graça  (351) 213 912 600    None
# 5                            Campo de Santa Clara   +351 218 533 270    None
# 6               Praça da Estrela\n1200-667 LISBOA   +351 213 960 915    None
# 7                           Rua Júlio de Andradel               None    None
# 8                       Largo das Portas do Sol\n   +351 213 912 600    None
# 9                           Avenida de Brasília\n   +351 213 031 950    None
# 10                        Rua Presidente Arriaga;   +351 213 912 600    None
# 11      Largo da Penha de França\n1170-298 LISBOA  (351) 213 912 600    None
# 12                         Largo de Santa Luzia\n               None    None
# 13                         Calçada de Santo Amaro               None    None
# 14                    Alameda Cardeal Cerejeira\n   +351 213 912 600    None
# 15                  Rua de São Pedro de Alcântara   +351 213 912 600    None
# 16                          Rua Heliodoro Salgado  (351) 213 912 600    None
# 17                 Avenida de Brasília\n1400-038    +351 213 620 034    None
# 18         Rua de Santa Catarina\n1200-403 LISBOA   +351 213 027 700    None
# 19                               Largo do Monte\n               None    None
#
#                           INF_EMAIL  \
# 0                              None
# 1              info@lismarketing.pt
# 2                 daev@cm-lisboa.pt
# 3         info@castelodesaojorge.pt
# 4                 daev@cm-lisboa.pt
# 5                 daev@cm-lisboa.pt
# 6                              None
# 7                              None
# 8                 daev@cm-lisboa.pt
# 9   info@padraodosdescobrimentos.pt
# 10                daev@cm-lisboa.pt
# 11                daev@cm-lisboa.pt
# 12                             None
# 13                             None
# 14                daev@cm-lisboa.pt
# 15                daev@cm-lisboa.pt
# 16                daev@cm-lisboa.pt
# 17            mjeronimos@igespar.pt
# 18                             None
# 19                             None
#
#                                              INF_SITE  \
# 0                                                None
# 1                                www.visitlisboa.com
# 2                                                None
# 3                            www.castelodesaojorge.pt
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                      www.padraodosdescobrimentos.pt
# 10  http://lisboaverde.cm-lisboa.pt/index.php?id=4345
# 11  http://lisboaverde.cm-lisboa.pt/index.php?id=5561
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                 www.torrebelem.pt/
# 18                                               None
# 19                                               None
#
#                                         INF_DESCRICAO  \
# 0   Localizado no Parque Florestal de Monsanto, na...
# 1                                                None
# 2   Situado no coração de Alfama, do adro da Igrej...
# 3   O Castelo de São Jorge oferece uma vista privi...
# 4   Localizado junto à Igreja e antigo Convento da...
# 5   É um ponto alto da cidade com vista panorâmica...
# 6   Do zimbório desfruta-se de bela vista: a oeste...
# 7   Deste miradouro disfruta-se de uma vista desaf...
# 8   Localizado no Largo das Portas do Sol, daí o s...
# 9   No terraço existe um espetacular miradouro, do...
# 10  Este miradouro, enquadrado por um conjunto de ...
# 11  Vista inesquecível quer para o Vale do Tejo co...
# 12  Uma das mais belas janelas sobre o rio Tejo e ...
# 13                                               None
# 14  Está integrado no PARQUE EDUARDO VII, e  tem u...
# 15  Do miradouro de São Pedro de Alcântara, locali...
# 16  Com uma vista deslumbrante sobre a cidade, o M...
# 17  Do terraço da torre tem-se ampla vista do estu...
# 18  A partir deste miradouro podemos observar o Te...
# 19  Junto à Capela da Senhora do Monte, este balcã...
#
#                                   INF_AUTOR_DESCRICAO             INF_FONTE  \
# 0                                                None                DMEVAE
# 1                                                None  www.visitlisboa.com
# 2                                                None                     -
# 3                                       Isabel Santos                     -
# 4   Oásis Alfacinhas: Guia Ambiental de Lisboa - I...                     -
# 5                                                None                     -
# 6                                                None                     -
# 7                                                None                     -
# 8   http://revelarlx.cm-lisboa.pt, www.guiadacidad...                     -
# 9                                                None                     -
# 10                   Oásis Alfacinhas - Isabel Santos                     -
# 11                                               None                     -
# 12                   Oásis Alfacinhas - Isabel Santos                     -
# 13                                               None                     -
# 14                                               None                     -
# 15  Guia: Lisboa,Uma cidade inesquecível, Oásis Al...                     -
# 16                                               None                     -
# 17                                               None                     -
# 18  Guia: Lisboa. Uma cidade inesquecível, Oásis A...                     -
# 19                                               None                     -
#
#    INF_OBS  INF_ACTIVO  INF_MUNICIPAL                              GlobalID  \
# 0     None           1              0  6eed37fd-2b1c-4d74-bf46-651b8b94737d
# 1     None           1              0  783577af-9715-49a8-a797-b6cef6a60d69
# 2   SG/DMC           1              0  51166c6a-a6bf-4d6a-9fdf-b2490dc737b6
# 3     None           1              0  8ced2062-5a41-479a-927f-d17cadd6352a
# 4     None           1              1  fd96eabc-2570-4094-831c-3c54e5a4133d
# 5   SG/DMC           1              0  8cf5bdec-709c-45c9-9c61-4be75aeb0146
# 6   SG-DMC           1              0  48fbfa88-0ee2-449a-a6fa-98bf29696738
# 7   SG/DMC           1              0  1cd6490b-e68e-4a34-9a27-c654ef3124e8
# 8     None           1              1  229ec52c-ec31-4bf4-a471-b4db75912df9
# 9     None           1              1  ce95a050-404d-4678-8cae-fdff207bc983
# 10    None           1              0  6f536056-3675-424e-9333-c3f9a3ed73e8
# 11  SG-DMC           1              0  3b560443-d244-43d0-a60e-91e9b505d0da
# 12    None           1              1  a6939081-dc3a-4335-a7f1-36d8a02f7a6c
# 13    None           1              0  44dbab8e-86a0-44ed-b190-ce166b834918
# 14  SG/DMC           1              0  8bb025f7-a443-48ab-9380-01e2de6a172c
# 15    None           1              0  ae865bdf-b7aa-4dd1-b8a0-231d35472b6c
# 16  SG-DMC           1              0  000efa7b-6c61-4974-8aee-9dca558cdccb
# 17  SG-DMC           1              0  3b5951f1-629e-4f48-932f-eac38b074e0b
# 18    None           1              0  f4b1ba6c-394d-4fbb-8c2d-7f7049faa687
# 19    None           1              1  eb681f37-e209-4fa5-976d-f3d4839de060
#
#                      geometry
# 0   POINT (-9.18461 38.72862)
# 1   POINT (-9.17955 38.70001)
# 2   POINT (-9.12773 38.71207)
# 3   POINT (-9.13421 38.71299)
# 4   POINT (-9.13158 38.71643)
# 5   POINT (-9.12469 38.71497)
# 6   POINT (-9.16058 38.71310)
# 7   POINT (-9.14129 38.71932)
# 8   POINT (-9.13037 38.71235)
# 9   POINT (-9.20570 38.69361)
# 10  POINT (-9.16277 38.70418)
# 11  POINT (-9.13155 38.73063)
# 12  POINT (-9.13036 38.71165)
# 13  POINT (-9.18237 38.70146)
# 14  POINT (-9.15448 38.73036)
# 15  POINT (-9.14428 38.71530)
# 16  POINT (-9.13153 38.72614)
# 17  POINT (-9.21593 38.69158)
# 18  POINT (-9.14767 38.70952)
# 19  POINT (-9.13299 38.71898)

# %%
df.shape
# Out:
# (20, 20)

# %% [markdown]
# The dataset contains a lot of information for each viewpoint of Lisbon. For this problem, the information needed is just the name (INF_NOME), adress (INF_MORADA) and spatial coordinates (geometry), so let's create a dataframe only with this information.

# %%
df_lisbonviews = df [["INF_NOME", "INF_MORADA", "geometry"]]
df_lisbonviews.columns = ['Viewpoint', 'Adress', 'Coordinates']

# %%
from shapely.wkt import loads as load_wkt

centroid_list = []

for polygon in df_lisbonviews["Coordinates"]:
    box_str = str(polygon)
    p1 = load_wkt(box_str)
    point = p1.centroid
#     print(type(p1.centroid.x))
#     print(p1.centroid.y)
    centroid_list.append((p1.centroid.y, p1.centroid.x))

lat_centr, lon_centr = zip(*centroid_list)

df_lisbonviews['Latitude'] = lat_centr
df_lisbonviews['Longitude'] = lon_centr

df_lisbonviews.drop(["Coordinates"], axis = 1, inplace = True) 
df_lisbonviews
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                             Viewpoint  \
# 0                 Miradouro do Panorâmico de Monsanto
# 1                                 Experiência Pilar 7
# 2                          Miradouro de Santo Estêvão
# 3                   Miradouro do Castelo de São Jorge
# 4   Miradouro Sophia de Mello Breyner Andresen (Mi...
# 5                            Miradouro de Santa Clara
# 6                    Miradouro da Basílica da Estrela
# 7                                  Miradouro do Torel
# 8                         Miradouro das Portas do Sol
# 9              Miradouro do Padrão dos Descobrimentos
# 10              Miradouro da Rocha de Conde de Óbidos
# 11                       Miradouro da Penha de França
# 12                           Miradouro de Santa Luzia
# 13                           Miradouro de Santo Amaro
# 14                    Miradouro do Parque Eduardo VII
# 15                Miradouro de São Pedro de Alcântara
# 16                           Miradouro do Monte Agudo
# 17                        Miradouro da Torre de Belém
# 18                        Miradouro de Santa Catarina
# 19                      Miradouro da Senhora do Monte
#
#                                            Adress   Latitude  Longitude
# 0                              Estrada Bela Vista  38.728618  -9.184607
# 1   Avenida da Índia, Ponte 25 de Abril - Pilar 7  38.700008  -9.179553
# 2                          Largo de Santo Estêvão  38.712070  -9.127729
# 3                            Castelo de São Jorge  38.712991  -9.134210
# 4                                  Largo da Graça  38.716427  -9.131584
# 5                            Campo de Santa Clara  38.714970  -9.124694
# 6               Praça da Estrela\n1200-667 LISBOA  38.713097  -9.160581
# 7                           Rua Júlio de Andradel  38.719323  -9.141286
# 8                       Largo das Portas do Sol\n  38.712346  -9.130366
# 9                           Avenida de Brasília\n  38.693614  -9.205697
# 10                        Rua Presidente Arriaga;  38.704181  -9.162765
# 11      Largo da Penha de França\n1170-298 LISBOA  38.730633  -9.131550
# 12                         Largo de Santa Luzia\n  38.711646  -9.130360
# 13                         Calçada de Santo Amaro  38.701464  -9.182371
# 14                    Alameda Cardeal Cerejeira\n  38.730358  -9.154480
# 15                  Rua de São Pedro de Alcântara  38.715299  -9.144277
# 16                          Rua Heliodoro Salgado  38.726145  -9.131528
# 17                 Avenida de Brasília\n1400-038   38.691578  -9.215928
# 18         Rua de Santa Catarina\n1200-403 LISBOA  38.709515  -9.147672
# 19                               Largo do Monte\n  38.718975  -9.132994

# %%
address = 'Lisbon'

geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Lisbon are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Lisbon are 38.7077507, -9.1365919.

# %%
map_lisbonviewpoints = folium.Map(location=[latitude, longitude], zoom_start=15)

# add markers to map
for lat, lng, viewpoint in zip(df_lisbonviews['Latitude'], 
                                          df_lisbonviews['Longitude'],  
                                           df_lisbonviews['Viewpoint']):
    label = '{}'.format(viewpoint)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=1.0,
        parse_html=False).add_to(map_lisbonviewpoints)  

map_lisbonviewpoints
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ac7723d2fbf441119c4f8f87a891dd2e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ac7723d2fbf441119c4f8f87a891dd2e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ac7723d2fbf441119c4f8f87a891dd2e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ac7723d2fbf441119c4f8f87a891dd2e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.7077507%2C%20-9.1365919%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
map_lisbonviewpoints2 = folium.Map([latitude, longitude], zoom_start=15)

folium.GeoJson(Lisbon_viewpoints_geodf,
    style_function=lambda x: {
        'color' : 'darkred',
        'opacity': 1.0,
        'fillColor' : 'darkred',
        }).add_to(map_lisbonviewpoints2)

map_lisbonviewpoints2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e04578657fa84f73aa60c5ce9334351b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e04578657fa84f73aa60c5ce9334351b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e04578657fa84f73aa60c5ce9334351b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e04578657fa84f73aa60c5ce9334351b%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.7077507%2C%20-9.1365919%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# Now it's time to use the foursquare API to examinate the city of Milan

# %%
CLIENT_ID = 'GM0MXCVLIDQ2RTLGBJJ0NJBXFYZFYOLBNCNOS102GWZYTXPF' # your Foursquare ID
CLIENT_SECRET = 'IOQ4NZ15N2RBYYRU2Y2CYUNQ0NZWGYWRWYCO3ZDU2XXL1PC5' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

# %% [markdown]
# Extract venues for each neighborhood in Milan

# %%
def getNearbyRestaurants(names, latitudes, longitudes, radius):
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        # print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&section=food&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        resp = requests.get(url).json()["response"]
        
        if "groups" in resp:
            results = resp['groups'][0]['items']
            # return only relevant information for each nearby venue
            venues_list.append([(
                name, 
                lat, 
                lng, 
                v['venue']['name'], 
                v['venue']['location']['lat'], 
                v['venue']['location']['lng'],  
                v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Viewpoint', 
                  'Viewpoint Latitude', 
                  'Viewpoint Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
lisbon_viewpoints_venues = getNearbyRestaurants(names=df_lisbonviews['Viewpoint'],
                                         latitudes=df_lisbonviews['Latitude'],
                                         longitudes=df_lisbonviews['Longitude'],
                                         radius=1000)

# %%
print(lisbon_viewpoints_venues.shape)
lisbon_viewpoints_venues.head(20)
# Out:
# (1733, 7)
#                               Viewpoint  Viewpoint Latitude  \
# 0   Miradouro do Panorâmico de Monsanto           38.728618
# 1   Miradouro do Panorâmico de Monsanto           38.728618
# 2   Miradouro do Panorâmico de Monsanto           38.728618
# 3   Miradouro do Panorâmico de Monsanto           38.728618
# 4   Miradouro do Panorâmico de Monsanto           38.728618
# 5                   Experiência Pilar 7           38.700008
# 6                   Experiência Pilar 7           38.700008
# 7                   Experiência Pilar 7           38.700008
# 8                   Experiência Pilar 7           38.700008
# 9                   Experiência Pilar 7           38.700008
# 10                  Experiência Pilar 7           38.700008
# 11                  Experiência Pilar 7           38.700008
# 12                  Experiência Pilar 7           38.700008
# 13                  Experiência Pilar 7           38.700008
# 14                  Experiência Pilar 7           38.700008
# 15                  Experiência Pilar 7           38.700008
# 16                  Experiência Pilar 7           38.700008
# 17                  Experiência Pilar 7           38.700008
# 18                  Experiência Pilar 7           38.700008
# 19                  Experiência Pilar 7           38.700008
#
#     Viewpoint Longitude                                Venue  Venue Latitude  \
# 0             -9.184607                       Messe Monsanto       38.729066
# 1             -9.184607                          Monte Verde       38.726703
# 2             -9.184607               Restaurante Monteverde       38.725040
# 3             -9.184607  Pastelaria Snack Bar Creme e Canela       38.724917
# 4             -9.184607                 Papagaio da Serafina       38.733658
# 5             -9.179553                  Village Underground       38.700861
# 6             -9.179553                        Rio Maravilha       38.701798
# 7             -9.179553                            5 Oceanos       38.699654
# 8             -9.179553                 A Padaria Portuguesa       38.702512
# 9             -9.179553                         1300 Taberna       38.702888
# 10            -9.179553                        Doca de Santo       38.700551
# 11            -9.179553                         Don Pomodoro       38.699638
# 12            -9.179553                       Rui dos Pregos       38.700079
# 13            -9.179553                        The Therapist       38.701634
# 14            -9.179553                             Cucurico       38.702564
# 15            -9.179553                            Café Dias       38.702917
# 16            -9.179553                            O Mercado       38.705005
# 17            -9.179553                   Cantina LX Factory       38.703228
# 18            -9.179553                          A Tapadinha       38.706576
# 19            -9.179553                            chef nino       38.703059
#
#     Venue Longitude               Venue Category
# 0         -9.189070        Portuguese Restaurant
# 1         -9.194175        Portuguese Restaurant
# 2         -9.190780        Portuguese Restaurant
# 3         -9.177665               Breakfast Spot
# 4         -9.177860        Portuguese Restaurant
# 5         -9.178150                         Café
# 6         -9.178076        Portuguese Restaurant
# 7         -9.178412           Seafood Restaurant
# 8         -9.180872                       Bakery
# 9         -9.178968                   Restaurant
# 10        -9.176251                   Restaurant
# 11        -9.178586           Italian Restaurant
# 12        -9.175933                   Steakhouse
# 13        -9.177599      Comfort Food Restaurant
# 14        -9.178860                    BBQ Joint
# 15        -9.184385                         Café
# 16        -9.178732     Mediterranean Restaurant
# 17        -9.178896        Portuguese Restaurant
# 18        -9.178730  Eastern European Restaurant
# 19        -9.178802                         Café

# %%
venues_unique = lisbon_viewpoints_venues.groupby(['Viewpoint',
                                         'Venue',         
                                         'Venue Latitude', 
                                         'Venue Longitude', 
                                         'Venue Category']).size().reset_index(name='Counts') 
venues_unique.head(10)
# Out:
#              Viewpoint                 Venue  Venue Latitude  Venue Longitude  \
# 0  Experiência Pilar 7          1300 Taberna       38.702888        -9.178968
# 1  Experiência Pilar 7             5 Oceanos       38.699654        -9.178412
# 2  Experiência Pilar 7  A Padaria Portuguesa       38.702512        -9.180872
# 3  Experiência Pilar 7               A Praça       38.703040        -9.178872
# 4  Experiência Pilar 7           A Tapadinha       38.706576        -9.178730
# 5  Experiência Pilar 7          Alcântara 50       38.705462        -9.173533
# 6  Experiência Pilar 7             Café Dias       38.702917        -9.184385
# 7  Experiência Pilar 7       Café na Fábrica       38.703206        -9.179032
# 8  Experiência Pilar 7              Campinas       38.700569        -9.182483
# 9  Experiência Pilar 7    Cantina LX Factory       38.703228        -9.178896
#
#                 Venue Category  Counts
# 0                   Restaurant       1
# 1           Seafood Restaurant       1
# 2                       Bakery       1
# 3           Italian Restaurant       1
# 4  Eastern European Restaurant       1
# 5        Portuguese Restaurant       1
# 6                         Café       1
# 7               Breakfast Spot       1
# 8                   Restaurant       1
# 9        Portuguese Restaurant       1

# %% [markdown]
# Now let's see all the points in a map

# %%
venues_map = folium.Map([latitude, longitude], zoom_start=12)

for label, lat, lng in zip(venues_unique['Venue'], 
                           venues_unique['Venue Latitude'], 
                           venues_unique['Venue Longitude']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        location=[lat, lng],
        radius=2,
        popup=label,
        color='red',
        fill=False,
        #fill_color='red',
        fill_opacity=0.6,
        parse_html=False
    ).add_to(map_lisbonviewpoints2)
   
from IPython.display import display
display(map_lisbonviewpoints2)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e04578657fa84f73aa60c5ce9334351b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e04578657fa84f73aa60c5ce9334351b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e04578657fa84f73aa60c5ce9334351b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e04578657fa84f73aa60c5ce9334351b%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.7077507%2C%20-9.1365919%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# With a group by "Neighborhood", I can easly see how many places I have

# %%
resDF = venues_unique.groupby('Viewpoint').size().reset_index(name='Counts') 
resDF
# Out:
#                                             Viewpoint  Counts
# 0                                 Experiência Pilar 7      44
# 1   Miradouro Sophia de Mello Breyner Andresen (Mi...     100
# 2                    Miradouro da Basílica da Estrela     100
# 3                        Miradouro da Penha de França     100
# 4               Miradouro da Rocha de Conde de Óbidos      88
# 5                       Miradouro da Senhora do Monte     100
# 6                         Miradouro da Torre de Belém      39
# 7                         Miradouro das Portas do Sol     100
# 8                         Miradouro de Santa Catarina     100
# 9                            Miradouro de Santa Clara     100
# 10                           Miradouro de Santa Luzia     100
# 11                           Miradouro de Santo Amaro      83
# 12                         Miradouro de Santo Estêvão     100
# 13                Miradouro de São Pedro de Alcântara     100
# 14                  Miradouro do Castelo de São Jorge     100
# 15                           Miradouro do Monte Agudo     100
# 16             Miradouro do Padrão dos Descobrimentos      74
# 17                Miradouro do Panorâmico de Monsanto       5
# 18                    Miradouro do Parque Eduardo VII     100
# 19                                 Miradouro do Torel     100

# %%
venueDF = venues_unique.groupby('Venue Category').size().reset_index(name='Counts')
venueDF.sort_values(by=['Counts'], ascending=False).head(10)
# Out:
#                    Venue Category  Counts
# 46          Portuguese Restaurant     502
# 48                     Restaurant     177
# 12                           Café     175
# 34              Indian Restaurant      84
# 7                          Bakery      75
# 38       Mediterranean Restaurant      64
# 65  Vegetarian / Vegan Restaurant      46
# 52             Seafood Restaurant      46
# 35             Italian Restaurant      41
# 44                    Pizza Place      35

# %%
lisbonviews_onehot = pd.get_dummies(venues_unique['Venue Category'])
lisbonviews_onehot.insert(loc=0, column='Viewpoint', value=venues_unique['Viewpoint'])
lisbonviews_grouped = lisbonviews_onehot.groupby('Viewpoint').mean().reset_index()
lisbonviews_grouped.head(10)
# Out:
#                                            Viewpoint  African Restaurant  \
# 0                                Experiência Pilar 7                0.00
# 1  Miradouro Sophia de Mello Breyner Andresen (Mi...                0.00
# 2                   Miradouro da Basílica da Estrela                0.01
# 3                       Miradouro da Penha de França                0.00
# 4              Miradouro da Rocha de Conde de Óbidos                0.00
# 5                      Miradouro da Senhora do Monte                0.00
# 6                        Miradouro da Torre de Belém                0.00
# 7                        Miradouro das Portas do Sol                0.02
# 8                        Miradouro de Santa Catarina                0.00
# 9                           Miradouro de Santa Clara                0.02
#
#    American Restaurant  Argentinian Restaurant  Asian Restaurant  \
# 0             0.000000                0.022727              0.00
# 1             0.010000                0.000000              0.01
# 2             0.000000                0.000000              0.00
# 3             0.000000                0.000000              0.02
# 4             0.011364                0.000000              0.00
# 5             0.010000                0.000000              0.01
# 6             0.000000                0.000000              0.00
# 7             0.000000                0.000000              0.00
# 8             0.000000                0.010000              0.01
# 9             0.000000                0.000000              0.01
#
#    Australian Restaurant  BBQ Joint  Bagel Shop    Bakery  Bistro  \
# 0                   0.00   0.045455        0.00  0.068182    0.00
# 1                   0.00   0.010000        0.00  0.050000    0.02
# 2                   0.01   0.020000        0.01  0.040000    0.01
# 3                   0.00   0.030000        0.01  0.070000    0.00
# 4                   0.00   0.022727        0.00  0.034091    0.00
# 5                   0.00   0.010000        0.00  0.050000    0.02
# 6                   0.00   0.000000        0.00  0.051282    0.00
# 7                   0.00   0.010000        0.00  0.020000    0.03
# 8                   0.01   0.000000        0.00  0.040000    0.02
# 9                   0.00   0.010000        0.00  0.050000    0.04
#
#    Brazilian Restaurant  Breakfast Spot  Burger Joint      Café  \
# 0                  0.00        0.022727      0.000000  0.090909
# 1                  0.01        0.020000      0.000000  0.130000
# 2                  0.00        0.040000      0.020000  0.080000
# 3                  0.01        0.010000      0.010000  0.160000
# 4                  0.00        0.022727      0.011364  0.056818
# 5                  0.01        0.030000      0.000000  0.140000
# 6                  0.00        0.000000      0.051282  0.179487
# 7                  0.01        0.010000      0.010000  0.110000
# 8                  0.02        0.020000      0.030000  0.060000
# 9                  0.00        0.030000      0.010000  0.130000
#
#    Cajun / Creole Restaurant  Chinese Restaurant  Comfort Food Restaurant  \
# 0                        0.0                0.00                 0.022727
# 1                        0.0                0.03                 0.010000
# 2                        0.0                0.01                 0.000000
# 3                        0.0                0.01                 0.000000
# 4                        0.0                0.00                 0.000000
# 5                        0.0                0.03                 0.010000
# 6                        0.0                0.00                 0.000000
# 7                        0.0                0.01                 0.010000
# 8                        0.0                0.00                 0.010000
# 9                        0.0                0.03                 0.010000
#
#    Creperie  Deli / Bodega     Diner  Doner Restaurant  \
# 0      0.00       0.000000  0.000000               0.0
# 1      0.01       0.000000  0.000000               0.0
# 2      0.00       0.010000  0.000000               0.0
# 3      0.00       0.010000  0.000000               0.0
# 4      0.00       0.011364  0.011364               0.0
# 5      0.01       0.000000  0.000000               0.0
# 6      0.00       0.000000  0.025641               0.0
# 7      0.01       0.000000  0.000000               0.0
# 8      0.00       0.020000  0.000000               0.0
# 9      0.01       0.010000  0.000000               0.0
#
#    Eastern European Restaurant  Empanada Restaurant  Falafel Restaurant  \
# 0                     0.022727                 0.00            0.000000
# 1                     0.000000                 0.01            0.000000
# 2                     0.000000                 0.00            0.010000
# 3                     0.000000                 0.00            0.000000
# 4                     0.000000                 0.00            0.011364
# 5                     0.000000                 0.01            0.000000
# 6                     0.000000                 0.00            0.000000
# 7                     0.000000                 0.01            0.000000
# 8                     0.000000                 0.00            0.000000
# 9                     0.000000                 0.01            0.000000
#
#    Fast Food Restaurant  Food Court  Food Stand  Food Truck  \
# 0              0.000000        0.00        0.00    0.000000
# 1              0.000000        0.00        0.01    0.010000
# 2              0.000000        0.00        0.00    0.000000
# 3              0.000000        0.00        0.00    0.000000
# 4              0.011364        0.00        0.00    0.000000
# 5              0.000000        0.00        0.01    0.010000
# 6              0.000000        0.00        0.00    0.051282
# 7              0.000000        0.00        0.00    0.010000
# 8              0.000000        0.02        0.00    0.000000
# 9              0.000000        0.00        0.01    0.010000
#
#    French Restaurant  Fried Chicken Joint  Gastropub  Greek Restaurant  \
# 0           0.000000                  0.0   0.000000          0.000000
# 1           0.000000                  0.0   0.010000          0.000000
# 2           0.010000                  0.0   0.000000          0.010000
# 3           0.000000                  0.0   0.000000          0.010000
# 4           0.011364                  0.0   0.000000          0.022727
# 5           0.000000                  0.0   0.010000          0.000000
# 6           0.000000                  0.0   0.025641          0.000000
# 7           0.000000                  0.0   0.010000          0.000000
# 8           0.010000                  0.0   0.030000          0.000000
# 9           0.000000                  0.0   0.000000          0.000000
#
#    Hawaiian Restaurant  Himalayan Restaurant  Hot Dog Joint  \
# 0                  0.0              0.000000       0.000000
# 1                  0.0              0.000000       0.000000
# 2                  0.0              0.000000       0.000000
# 3                  0.0              0.000000       0.000000
# 4                  0.0              0.011364       0.000000
# 5                  0.0              0.000000       0.000000
# 6                  0.0              0.000000       0.025641
# 7                  0.0              0.000000       0.000000
# 8                  0.0              0.000000       0.000000
# 9                  0.0              0.000000       0.000000
#
#    Indian Restaurant  Italian Restaurant  Japanese Restaurant  \
# 0           0.022727            0.045455             0.000000
# 1           0.080000            0.000000             0.000000
# 2           0.050000            0.050000             0.030000
# 3           0.110000            0.050000             0.000000
# 4           0.022727            0.045455             0.022727
# 5           0.080000            0.000000             0.000000
# 6           0.025641            0.000000             0.051282
# 7           0.060000            0.000000             0.000000
# 8           0.010000            0.040000             0.000000
# 9           0.030000            0.000000             0.000000
#
#    Malay Restaurant  Mediterranean Restaurant  Mexican Restaurant  \
# 0               0.0                  0.113636            0.000000
# 1               0.0                  0.050000            0.000000
# 2               0.0                  0.010000            0.000000
# 3               0.0                  0.000000            0.000000
# 4               0.0                  0.056818            0.022727
# 5               0.0                  0.030000            0.000000
# 6               0.0                  0.025641            0.000000
# 7               0.0                  0.060000            0.000000
# 8               0.0                  0.020000            0.010000
# 9               0.0                  0.060000            0.000000
#
#    Middle Eastern Restaurant  Modern European Restaurant  Pastelaria  \
# 0                       0.00                        0.00    0.000000
# 1                       0.00                        0.00    0.000000
# 2                       0.01                        0.00    0.000000
# 3                       0.02                        0.00    0.000000
# 4                       0.00                        0.00    0.000000
# 5                       0.00                        0.01    0.000000
# 6                       0.00                        0.00    0.025641
# 7                       0.00                        0.00    0.000000
# 8                       0.01                        0.01    0.000000
# 9                       0.00                        0.00    0.000000
#
#    Peruvian Restaurant  Pizza Place  Poke Place  Portuguese Restaurant  \
# 0                 0.00     0.045455         0.0               0.159091
# 1                 0.00     0.010000         0.0               0.340000
# 2                 0.00     0.010000         0.0               0.260000
# 3                 0.00     0.030000         0.0               0.210000
# 4                 0.00     0.011364         0.0               0.238636
# 5                 0.00     0.020000         0.0               0.310000
# 6                 0.00     0.025641         0.0               0.230769
# 7                 0.01     0.020000         0.0               0.400000
# 8                 0.03     0.010000         0.0               0.270000
# 9                 0.00     0.020000         0.0               0.350000
#
#    Ramen Restaurant  Restaurant  Russian Restaurant  Salad Place  \
# 0              0.00    0.227273                 0.0         0.00
# 1              0.01    0.060000                 0.0         0.01
# 2              0.01    0.070000                 0.0         0.00
# 3              0.01    0.090000                 0.0         0.00
# 4              0.00    0.136364                 0.0         0.00
# 5              0.01    0.060000                 0.0         0.01
# 6              0.00    0.102564                 0.0         0.00
# 7              0.01    0.070000                 0.0         0.01
# 8              0.00    0.110000                 0.0         0.00
# 9              0.00    0.040000                 0.0         0.01
#
#    Sandwich Place  Seafood Restaurant  Snack Place  Soup Place  \
# 0        0.000000            0.045455     0.000000    0.000000
# 1        0.010000            0.030000     0.010000    0.000000
# 2        0.000000            0.050000     0.010000    0.000000
# 3        0.010000            0.030000     0.020000    0.000000
# 4        0.000000            0.045455     0.011364    0.022727
# 5        0.010000            0.040000     0.000000    0.000000
# 6        0.025641            0.025641     0.000000    0.000000
# 7        0.010000            0.010000     0.020000    0.000000
# 8        0.000000            0.030000     0.000000    0.000000
# 9        0.010000            0.020000     0.000000    0.000000
#
#    South American Restaurant  South Indian Restaurant  Spanish Restaurant  \
# 0                   0.000000                     0.00                 0.0
# 1                   0.000000                     0.00                 0.0
# 2                   0.010000                     0.00                 0.0
# 3                   0.000000                     0.01                 0.0
# 4                   0.011364                     0.00                 0.0
# 5                   0.000000                     0.00                 0.0
# 6                   0.000000                     0.00                 0.0
# 7                   0.000000                     0.00                 0.0
# 8                   0.010000                     0.00                 0.0
# 9                   0.000000                     0.00                 0.0
#
#    Steakhouse  Sushi Restaurant  Swiss Restaurant  Taco Place  \
# 0    0.022727          0.022727              0.00        0.00
# 1    0.000000          0.000000              0.00        0.00
# 2    0.040000          0.010000              0.01        0.00
# 3    0.010000          0.000000              0.00        0.01
# 4    0.022727          0.011364              0.00        0.00
# 5    0.000000          0.000000              0.00        0.00
# 6    0.000000          0.051282              0.00        0.00
# 7    0.000000          0.000000              0.00        0.00
# 8    0.010000          0.000000              0.01        0.00
# 9    0.000000          0.010000              0.00        0.00
#
#    Tapas Restaurant  Thai Restaurant  Turkish Restaurant  \
# 0          0.000000              0.0            0.000000
# 1          0.010000              0.0            0.000000
# 2          0.030000              0.0            0.000000
# 3          0.000000              0.0            0.000000
# 4          0.034091              0.0            0.011364
# 5          0.010000              0.0            0.000000
# 6          0.000000              0.0            0.000000
# 7          0.010000              0.0            0.000000
# 8          0.060000              0.0            0.000000
# 9          0.010000              0.0            0.000000
#
#    Vegetarian / Vegan Restaurant  Vietnamese Restaurant  Wings Joint
# 0                       0.000000                   0.00         0.00
# 1                       0.030000                   0.00         0.00
# 2                       0.050000                   0.00         0.00
# 3                       0.030000                   0.00         0.01
# 4                       0.022727                   0.00         0.00
# 5                       0.040000                   0.00         0.00
# 6                       0.000000                   0.00         0.00
# 7                       0.030000                   0.00         0.00
# 8                       0.050000                   0.00         0.00
# 9                       0.040000                   0.01         0.00

# %% [markdown]
# This function return the most common venues for each row

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# extract the first ten venues for every neighborhood

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Viewpoint']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
lisbonviewpoint_venues_sorted = pd.DataFrame(columns=columns)
lisbonviewpoint_venues_sorted['Viewpoint'] = lisbonviews_grouped['Viewpoint']

for ind in np.arange(lisbonviews_grouped.shape[0]):
    lisbonviewpoint_venues_sorted.iloc[ind, 1:] = return_most_common_venues(lisbonviews_grouped.iloc[ind, :], num_top_venues)

lisbonviewpoint_venues_sorted.head(10)
# Out:
#                                            Viewpoint  1st Most Common Venue  \
# 0                                Experiência Pilar 7             Restaurant
# 1  Miradouro Sophia de Mello Breyner Andresen (Mi...  Portuguese Restaurant
# 2                   Miradouro da Basílica da Estrela  Portuguese Restaurant
# 3                       Miradouro da Penha de França  Portuguese Restaurant
# 4              Miradouro da Rocha de Conde de Óbidos  Portuguese Restaurant
# 5                      Miradouro da Senhora do Monte  Portuguese Restaurant
# 6                        Miradouro da Torre de Belém  Portuguese Restaurant
# 7                        Miradouro das Portas do Sol  Portuguese Restaurant
# 8                        Miradouro de Santa Catarina  Portuguese Restaurant
# 9                           Miradouro de Santa Clara  Portuguese Restaurant
#
#    2nd Most Common Venue     3rd Most Common Venue  \
# 0  Portuguese Restaurant  Mediterranean Restaurant
# 1                   Café         Indian Restaurant
# 2                   Café                Restaurant
# 3                   Café         Indian Restaurant
# 4             Restaurant                      Café
# 5                   Café         Indian Restaurant
# 6                   Café                Restaurant
# 7                   Café                Restaurant
# 8             Restaurant          Tapas Restaurant
# 9                   Café  Mediterranean Restaurant
#
#            4th Most Common Venue          5th Most Common Venue  \
# 0                           Café                         Bakery
# 1                     Restaurant       Mediterranean Restaurant
# 2  Vegetarian / Vegan Restaurant             Seafood Restaurant
# 3                     Restaurant                         Bakery
# 4       Mediterranean Restaurant             Italian Restaurant
# 5                     Restaurant                         Bakery
# 6                     Food Truck            Japanese Restaurant
# 7              Indian Restaurant       Mediterranean Restaurant
# 8                           Café  Vegetarian / Vegan Restaurant
# 9                         Bakery                         Bistro
#
#            6th Most Common Venue          7th Most Common Venue  \
# 0             Seafood Restaurant             Italian Restaurant
# 1                         Bakery             Chinese Restaurant
# 2              Indian Restaurant             Italian Restaurant
# 3             Italian Restaurant  Vegetarian / Vegan Restaurant
# 4             Seafood Restaurant               Tapas Restaurant
# 5  Vegetarian / Vegan Restaurant             Seafood Restaurant
# 6               Sushi Restaurant                         Bakery
# 7  Vegetarian / Vegan Restaurant                         Bistro
# 8             Italian Restaurant                         Bakery
# 9  Vegetarian / Vegan Restaurant                     Restaurant
#
#            8th Most Common Venue     9th Most Common Venue  \
# 0                    Pizza Place                 BBQ Joint
# 1  Vegetarian / Vegan Restaurant        Seafood Restaurant
# 2                 Breakfast Spot                    Bakery
# 3             Seafood Restaurant               Pizza Place
# 4                         Bakery            Breakfast Spot
# 5                 Breakfast Spot  Mediterranean Restaurant
# 6                   Burger Joint        Seafood Restaurant
# 7             African Restaurant               Snack Place
# 8             Seafood Restaurant       Peruvian Restaurant
# 9              Indian Restaurant        Chinese Restaurant
#
#   10th Most Common Venue
# 0       Sushi Restaurant
# 1         Breakfast Spot
# 2             Steakhouse
# 3              BBQ Joint
# 4     Mexican Restaurant
# 5     Chinese Restaurant
# 6      Indian Restaurant
# 7            Pizza Place
# 8              Gastropub
# 9         Breakfast Spot

# %% [markdown]
# ### Clustering

# %% [markdown]
# The first step is identify the best “K” using a famous analytical approach: the elbow method

# %%
from sklearn.cluster import KMeans

# set number of clusters
kclusters = 5

lisbonviews_clustering = lisbonviews_grouped.drop('Viewpoint', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(lisbonviews_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 1, 3, 4, 3, 1, 4, 1, 3, 1], dtype=int32)

# %%
# cluster and top 10 venues for each neighborhood

# add clustering labels
lisbonviewpoint_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

lisbonviewpoint_merged = df_lisbonviews

# merge manhattan_grouped with manhattan_data to add latitude/longitude for each neighborhood
lisbonviewpoint_merged = lisbonviewpoint_merged.join(lisbonviewpoint_venues_sorted.set_index('Viewpoint'), on='Viewpoint')

lisbonviewpoint_venues_sorted.head()
# Out:
#    Cluster Labels                                          Viewpoint  \
# 0               0                                Experiência Pilar 7
# 1               1  Miradouro Sophia de Mello Breyner Andresen (Mi...
# 2               3                   Miradouro da Basílica da Estrela
# 3               4                       Miradouro da Penha de França
# 4               3              Miradouro da Rocha de Conde de Óbidos
#
#    1st Most Common Venue  2nd Most Common Venue     3rd Most Common Venue  \
# 0             Restaurant  Portuguese Restaurant  Mediterranean Restaurant
# 1  Portuguese Restaurant                   Café         Indian Restaurant
# 2  Portuguese Restaurant                   Café                Restaurant
# 3  Portuguese Restaurant                   Café         Indian Restaurant
# 4  Portuguese Restaurant             Restaurant                      Café
#
#            4th Most Common Venue     5th Most Common Venue  \
# 0                           Café                    Bakery
# 1                     Restaurant  Mediterranean Restaurant
# 2  Vegetarian / Vegan Restaurant        Seafood Restaurant
# 3                     Restaurant                    Bakery
# 4       Mediterranean Restaurant        Italian Restaurant
#
#   6th Most Common Venue          7th Most Common Venue  \
# 0    Seafood Restaurant             Italian Restaurant
# 1                Bakery             Chinese Restaurant
# 2     Indian Restaurant             Italian Restaurant
# 3    Italian Restaurant  Vegetarian / Vegan Restaurant
# 4    Seafood Restaurant               Tapas Restaurant
#
#            8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0                    Pizza Place             BBQ Joint       Sushi Restaurant
# 1  Vegetarian / Vegan Restaurant    Seafood Restaurant         Breakfast Spot
# 2                 Breakfast Spot                Bakery             Steakhouse
# 3             Seafood Restaurant           Pizza Place              BBQ Joint
# 4                         Bakery        Breakfast Spot     Mexican Restaurant

# %%
lisbonviewpoint_merged.head()
# Out:
#                                            Viewpoint  \
# 0                Miradouro do Panorâmico de Monsanto
# 1                                Experiência Pilar 7
# 2                         Miradouro de Santo Estêvão
# 3                  Miradouro do Castelo de São Jorge
# 4  Miradouro Sophia de Mello Breyner Andresen (Mi...
#
#                                           Adress   Latitude  Longitude  \
# 0                             Estrada Bela Vista  38.728618  -9.184607
# 1  Avenida da Índia, Ponte 25 de Abril - Pilar 7  38.700008  -9.179553
# 2                         Largo de Santo Estêvão  38.712070  -9.127729
# 3                           Castelo de São Jorge  38.712991  -9.134210
# 4                                 Largo da Graça  38.716427  -9.131584
#
#    Cluster Labels  1st Most Common Venue  2nd Most Common Venue  \
# 0               2  Portuguese Restaurant         Breakfast Spot
# 1               0             Restaurant  Portuguese Restaurant
# 2               1  Portuguese Restaurant                   Café
# 3               1  Portuguese Restaurant             Restaurant
# 4               1  Portuguese Restaurant                   Café
#
#       3rd Most Common Venue 4th Most Common Venue     5th Most Common Venue  \
# 0               Wings Joint  Fast Food Restaurant          Doner Restaurant
# 1  Mediterranean Restaurant                  Café                    Bakery
# 2  Mediterranean Restaurant            Restaurant         Indian Restaurant
# 3                      Café     Indian Restaurant  Mediterranean Restaurant
# 4         Indian Restaurant            Restaurant  Mediterranean Restaurant
#
#          6th Most Common Venue 7th Most Common Venue  \
# 0  Eastern European Restaurant   Empanada Restaurant
# 1           Seafood Restaurant    Italian Restaurant
# 2                       Bakery              Creperie
# 3                       Bistro    Chinese Restaurant
# 4                       Bakery    Chinese Restaurant
#
#            8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0             Falafel Restaurant            Food Court          Deli / Bodega
# 1                    Pizza Place             BBQ Joint       Sushi Restaurant
# 2                         Bistro        Breakfast Spot            Snack Place
# 3                    Pizza Place          Burger Joint     Seafood Restaurant
# 4  Vegetarian / Vegan Restaurant    Seafood Restaurant         Breakfast Spot

# %% [markdown]
# Before to start to analyze all the clusters, let’s take a look on a folium map

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(lisbonviewpoint_merged['Latitude'], lisbonviewpoint_merged['Longitude'], lisbonviewpoint_merged['Viewpoint'], lisbonviewpoint_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=10,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2e515e1495c341abbba09abdca183e9a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2e515e1495c341abbba09abdca183e9a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2e515e1495c341abbba09abdca183e9a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2e515e1495c341abbba09abdca183e9a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.7077507%2C%20-9.1365919%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# Examine Clusters

# %%
#Cluster 1
lisbonviewpoint_merged.loc[lisbonviewpoint_merged['Cluster Labels'] == 0, lisbonviewpoint_merged.columns[[0] + list(range(5, lisbonviewpoint_merged.shape[1]))]]
# Out:
#                           Viewpoint  1st Most Common Venue  \
# 1               Experiência Pilar 7             Restaurant
# 13         Miradouro de Santo Amaro             Restaurant
# 14  Miradouro do Parque Eduardo VII  Portuguese Restaurant
#
#     2nd Most Common Venue     3rd Most Common Venue     4th Most Common Venue  \
# 1   Portuguese Restaurant  Mediterranean Restaurant                      Café
# 13  Portuguese Restaurant                      Café  Mediterranean Restaurant
# 14             Restaurant        Italian Restaurant                      Café
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 1                 Bakery    Seafood Restaurant    Italian Restaurant
# 13    Italian Restaurant    Seafood Restaurant                Bakery
# 14   Japanese Restaurant                Bakery          Burger Joint
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 1            Pizza Place             BBQ Joint       Sushi Restaurant
# 13             BBQ Joint           Pizza Place           Burger Joint
# 14            Steakhouse      Sushi Restaurant            Snack Place

# %%
#Cluster 2
lisbonviewpoint_merged.loc[lisbonviewpoint_merged['Cluster Labels'] == 1, lisbonviewpoint_merged.columns[[0] + list(range(5, lisbonviewpoint_merged.shape[1]))]]
# Out:
#                                             Viewpoint  1st Most Common Venue  \
# 2                          Miradouro de Santo Estêvão  Portuguese Restaurant
# 3                   Miradouro do Castelo de São Jorge  Portuguese Restaurant
# 4   Miradouro Sophia de Mello Breyner Andresen (Mi...  Portuguese Restaurant
# 5                            Miradouro de Santa Clara  Portuguese Restaurant
# 8                         Miradouro das Portas do Sol  Portuguese Restaurant
# 12                           Miradouro de Santa Luzia  Portuguese Restaurant
# 19                      Miradouro da Senhora do Monte  Portuguese Restaurant
#
#    2nd Most Common Venue     3rd Most Common Venue 4th Most Common Venue  \
# 2                   Café  Mediterranean Restaurant            Restaurant
# 3             Restaurant                      Café     Indian Restaurant
# 4                   Café         Indian Restaurant            Restaurant
# 5                   Café  Mediterranean Restaurant                Bakery
# 8                   Café                Restaurant     Indian Restaurant
# 12                  Café                Restaurant     Indian Restaurant
# 19                  Café         Indian Restaurant            Restaurant
#
#        5th Most Common Venue          6th Most Common Venue  \
# 2          Indian Restaurant                         Bakery
# 3   Mediterranean Restaurant                         Bistro
# 4   Mediterranean Restaurant                         Bakery
# 5                     Bistro  Vegetarian / Vegan Restaurant
# 8   Mediterranean Restaurant  Vegetarian / Vegan Restaurant
# 12  Mediterranean Restaurant                         Bistro
# 19                    Bakery  Vegetarian / Vegan Restaurant
#
#    7th Most Common Venue          8th Most Common Venue  \
# 2               Creperie                         Bistro
# 3     Chinese Restaurant                    Pizza Place
# 4     Chinese Restaurant  Vegetarian / Vegan Restaurant
# 5             Restaurant              Indian Restaurant
# 8                 Bistro             African Restaurant
# 12          Burger Joint                    Pizza Place
# 19    Seafood Restaurant                 Breakfast Spot
#
#        9th Most Common Venue 10th Most Common Venue
# 2             Breakfast Spot            Snack Place
# 3               Burger Joint     Seafood Restaurant
# 4         Seafood Restaurant         Breakfast Spot
# 5         Chinese Restaurant         Breakfast Spot
# 8                Snack Place            Pizza Place
# 12               Snack Place     African Restaurant
# 19  Mediterranean Restaurant     Chinese Restaurant

# %%
#Cluster 3
lisbonviewpoint_merged.loc[lisbonviewpoint_merged['Cluster Labels'] == 2, lisbonviewpoint_merged.columns[[0] + list(range(5, lisbonviewpoint_merged.shape[1]))]]
# Out:
#                              Viewpoint  1st Most Common Venue  \
# 0  Miradouro do Panorâmico de Monsanto  Portuguese Restaurant
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0        Breakfast Spot           Wings Joint  Fast Food Restaurant
#
#   5th Most Common Venue        6th Most Common Venue 7th Most Common Venue  \
# 0      Doner Restaurant  Eastern European Restaurant   Empanada Restaurant
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0    Falafel Restaurant            Food Court          Deli / Bodega

# %%
#Cluster 4
lisbonviewpoint_merged.loc[lisbonviewpoint_merged['Cluster Labels'] == 3, lisbonviewpoint_merged.columns[[0] + list(range(5, lisbonviewpoint_merged.shape[1]))]]
# Out:
#                                  Viewpoint  1st Most Common Venue  \
# 6         Miradouro da Basílica da Estrela  Portuguese Restaurant
# 7                       Miradouro do Torel  Portuguese Restaurant
# 9   Miradouro do Padrão dos Descobrimentos  Portuguese Restaurant
# 10   Miradouro da Rocha de Conde de Óbidos  Portuguese Restaurant
# 15     Miradouro de São Pedro de Alcântara  Portuguese Restaurant
# 18             Miradouro de Santa Catarina  Portuguese Restaurant
#
#    2nd Most Common Venue 3rd Most Common Venue          4th Most Common Venue  \
# 6                   Café            Restaurant  Vegetarian / Vegan Restaurant
# 7             Restaurant                  Café  Vegetarian / Vegan Restaurant
# 9             Restaurant                  Café                     Food Truck
# 10            Restaurant                  Café       Mediterranean Restaurant
# 15            Restaurant                  Café              Indian Restaurant
# 18            Restaurant      Tapas Restaurant                           Café
#
#             5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 6              Seafood Restaurant     Indian Restaurant    Italian Restaurant
# 7               Indian Restaurant      Tapas Restaurant        Breakfast Spot
# 9        Mediterranean Restaurant        Sandwich Place                Bakery
# 10             Italian Restaurant    Seafood Restaurant      Tapas Restaurant
# 15               Tapas Restaurant          Burger Joint    Seafood Restaurant
# 18  Vegetarian / Vegan Restaurant    Italian Restaurant                Bakery
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 6         Breakfast Spot                Bakery             Steakhouse
# 7            Pizza Place             Gastropub                 Bakery
# 9              BBQ Joint      Sushi Restaurant    Japanese Restaurant
# 10                Bakery        Breakfast Spot     Mexican Restaurant
# 15   Peruvian Restaurant           Pizza Place     Russian Restaurant
# 18    Seafood Restaurant   Peruvian Restaurant              Gastropub

# %%
#Cluster 5 
lisbonviewpoint_merged.loc[lisbonviewpoint_merged['Cluster Labels'] == 4, lisbonviewpoint_merged.columns[[0] + list(range(5, lisbonviewpoint_merged.shape[1]))]]
# Out:
#                        Viewpoint  1st Most Common Venue 2nd Most Common Venue  \
# 11  Miradouro da Penha de França  Portuguese Restaurant                  Café
# 16      Miradouro do Monte Agudo  Portuguese Restaurant                  Café
# 17   Miradouro da Torre de Belém  Portuguese Restaurant                  Café
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 11     Indian Restaurant            Restaurant                Bakery
# 16                Bakery     Indian Restaurant            Restaurant
# 17            Restaurant            Food Truck   Japanese Restaurant
#
#    6th Most Common Venue          7th Most Common Venue  \
# 11    Italian Restaurant  Vegetarian / Vegan Restaurant
# 16             BBQ Joint             Seafood Restaurant
# 17      Sushi Restaurant                         Bakery
#
#             8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 11             Seafood Restaurant           Pizza Place              BBQ Joint
# 16  Vegetarian / Vegan Restaurant    Italian Restaurant            Pizza Place
# 17                   Burger Joint    Seafood Restaurant      Indian Restaurant
